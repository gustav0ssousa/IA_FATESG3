# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# CARREGANDO DATASET

df = pd.read_csv("telecom_churn_synthetic.csv")
print("Forma do dataset (linhas x colunas)")
print(df.shape)
# Out:
# Forma do dataset (linhas x colunas)
# (6000, 27)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure_months', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges',
#        'complaints_last_3m', 'outages_last_3m', 'avg_download_mbps',
#        'late_payments_last_6m', 'promo_active', 'discount_pct', 'churn'],
#       dtype='str')

# %%
df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure_months  \
# 0       C0000001    Male               0      No         No             52
# 1       C0000002  Female               0      No        Yes             49
# 2       C0000003    Male               0      No        Yes             61
# 3       C0000004    Male               0     Yes         No              6
# 4       C0000005  Female               0      No        Yes             23
# ...          ...     ...             ...     ...        ...            ...
# 5995    C0005996  Female               0      No         No             11
# 5996    C0005997    Male               0     Yes         No             15
# 5997    C0005998    Male               0     Yes        Yes              6
# 5998    C0005999    Male               0     Yes         No             11
# 5999    C0006000    Male               0      No         No             55
#
#      phone_service    multiple_lines internet_service      online_security  \
# 0              Yes               Yes      Fiber optic                   No
# 1              Yes                No              DSL                   No
# 2              Yes                No      Fiber optic                  Yes
# 3              Yes               Yes              DSL                   No
# 4              Yes               Yes      Fiber optic                   No
# ...            ...               ...              ...                  ...
# 5995           Yes                No               No  No internet service
# 5996           Yes                No               No  No internet service
# 5997           Yes                No      Fiber optic                  Yes
# 5998           Yes                No              DSL                   No
# 5999            No  No phone service      Fiber optic                   No
#
#       ...             payment_method monthly_charges total_charges  \
# 0     ...               Mailed check          111.37       5814.37
# 1     ...           Electronic check           33.94       1674.85
# 2     ...  Bank transfer (automatic)          101.19       6167.86
# 3     ...           Electronic check           77.53        444.59
# 4     ...               Mailed check           67.96       1541.46
# ...   ...                        ...             ...           ...
# 5995  ...    Credit card (automatic)           37.33        414.38
# 5996  ...  Bank transfer (automatic)           18.00        250.89
# 5997  ...               Mailed check           77.56        528.06
# 5998  ...  Bank transfer (automatic)           49.86        521.75
# 5999  ...           Electronic check          103.39       5724.26
#
#      complaints_last_3m outages_last_3m avg_download_mbps  \
# 0                     0               1             209.6
# 1                     0               3              41.2
# 2                     2               0             173.4
# 3                     1               0              34.8
# 4                     0               1             222.3
# ...                 ...             ...               ...
# 5995                  0               0               0.0
# 5996                  1               2               0.0
# 5997                  0               0             104.2
# 5998                  0               0              17.1
# 5999                  0               0             172.5
#
#      late_payments_last_6m promo_active  discount_pct  churn
# 0                        0          Yes          24.0      0
# 1                        2           No           0.0      0
# 2                        0           No           0.0      0
# 3                        2           No           0.0      0
# 4                        0           No           0.0      0
# ...                    ...          ...           ...    ...
# 5995                     0          Yes          12.5      0
# 5996                     0           No           0.0      0
# 5997                     1           No           0.0      0
# 5998                     0           No           0.0      0
# 5999                     0           No           0.0      0
#
# [6000 rows x 27 columns]

# %%
df.describe()
# Out:
#        senior_citizen  tenure_months  monthly_charges  total_charges  \
# count     6000.000000    6000.000000      6000.000000    5926.000000
# mean         0.156500      28.685000        69.063478    1977.805548
# std          0.363359      22.306495        28.521629    1860.606539
# min          0.000000       0.000000        18.000000       0.000000
# 25%          0.000000       8.000000        50.870000     468.655000
# 50%          0.000000      24.000000        72.640000    1303.255000
# 75%          0.000000      47.250000        89.690000    3166.367500
# max          1.000000      72.000000       140.000000    9809.360000
#
#        complaints_last_3m  outages_last_3m  avg_download_mbps  \
# count         6000.000000      6000.000000        5954.000000
# mean             0.408833         0.470167          85.650420
# std              0.654288         0.701089          77.047655
# min              0.000000         0.000000           0.000000
# 25%              0.000000         0.000000          21.800000
# 50%              0.000000         0.000000          48.400000
# 75%              1.000000         1.000000         154.300000
# max              5.000000         5.000000         330.000000
#
#        late_payments_last_6m  discount_pct        churn
# count            6000.000000   6000.000000  6000.000000
# mean                0.389500      3.272383     0.140500
# std                 0.659188      6.152472     0.347534
# min                 0.000000      0.000000     0.000000
# 25%                 0.000000      0.000000     0.000000
# 50%                 0.000000      0.000000     0.000000
# 75%                 1.000000      3.300000     0.000000
# max                 5.000000     35.000000     1.000000

# %%
df.describe(include='all').T
# Out:
#                         count unique               top  freq         mean  \
# customer_id              6000   6000          C0000001     1          NaN
# gender                   6000      2              Male  3012          NaN
# senior_citizen         6000.0    NaN               NaN   NaN       0.1565
# partner                  6000      2                No  3317          NaN
# dependents               6000      2                No  4156          NaN
# tenure_months          6000.0    NaN               NaN   NaN       28.685
# phone_service            6000      2               Yes  5394          NaN
# multiple_lines           6000      3                No  2947          NaN
# internet_service         6000      3       Fiber optic  2757          NaN
# online_security          6000      3                No  3261          NaN
# online_backup            6000      3                No  3049          NaN
# device_protection        6000      3                No  3184          NaN
# tech_support             6000      3                No  3338          NaN
# streaming_tv             6000      3                No  2628          NaN
# streaming_movies         6000      3                No  2651          NaN
# contract                 6000      3    Month-to-month  3377          NaN
# paperless_billing        6000      2               Yes  3516          NaN
# payment_method           6000      4  Electronic check  1978          NaN
# monthly_charges        6000.0    NaN               NaN   NaN    69.063478
# total_charges          5926.0    NaN               NaN   NaN  1977.805548
# complaints_last_3m     6000.0    NaN               NaN   NaN     0.408833
# outages_last_3m        6000.0    NaN               NaN   NaN     0.470167
# avg_download_mbps      5954.0    NaN               NaN   NaN     85.65042
# late_payments_last_6m  6000.0    NaN               NaN   NaN       0.3895
# promo_active             6000      2                No  4355          NaN
# discount_pct           6000.0    NaN               NaN   NaN     3.272383
# churn                  6000.0    NaN               NaN   NaN       0.1405
#
#                                std   min      25%       50%        75%  \
# customer_id                    NaN   NaN      NaN       NaN        NaN
# gender                         NaN   NaN      NaN       NaN        NaN
# senior_citizen            0.363359   0.0      0.0       0.0        0.0
# partner                        NaN   NaN      NaN       NaN        NaN
# dependents                     NaN   NaN      NaN       NaN        NaN
# tenure_months            22.306495   0.0      8.0      24.0      47.25
# phone_service                  NaN   NaN      NaN       NaN        NaN
# multiple_lines                 NaN   NaN      NaN       NaN        NaN
# internet_service               NaN   NaN      NaN       NaN        NaN
# online_security                NaN   NaN      NaN       NaN        NaN
# online_backup                  NaN   NaN      NaN       NaN        NaN
# device_protection              NaN   NaN      NaN       NaN        NaN
# tech_support                   NaN   NaN      NaN       NaN        NaN
# streaming_tv                   NaN   NaN      NaN       NaN        NaN
# streaming_movies               NaN   NaN      NaN       NaN        NaN
# contract                       NaN   NaN      NaN       NaN        NaN
# paperless_billing              NaN   NaN      NaN       NaN        NaN
# payment_method                 NaN   NaN      NaN       NaN        NaN
# monthly_charges          28.521629  18.0    50.87     72.64      89.69
# total_charges          1860.606539   0.0  468.655  1303.255  3166.3675
# complaints_last_3m        0.654288   0.0      0.0       0.0        1.0
# outages_last_3m           0.701089   0.0      0.0       0.0        1.0
# avg_download_mbps        77.047655   0.0     21.8      48.4      154.3
# late_payments_last_6m     0.659188   0.0      0.0       0.0        1.0
# promo_active                   NaN   NaN      NaN       NaN        NaN
# discount_pct              6.152472   0.0      0.0       0.0        3.3
# churn                     0.347534   0.0      0.0       0.0        0.0
#
#                            max
# customer_id                NaN
# gender                     NaN
# senior_citizen             1.0
# partner                    NaN
# dependents                 NaN
# tenure_months             72.0
# phone_service              NaN
# multiple_lines             NaN
# internet_service           NaN
# online_security            NaN
# online_backup              NaN
# device_protection          NaN
# tech_support               NaN
# streaming_tv               NaN
# streaming_movies           NaN
# contract                   NaN
# paperless_billing          NaN
# payment_method             NaN
# monthly_charges          140.0
# total_charges          9809.36
# complaints_last_3m         5.0
# outages_last_3m            5.0
# avg_download_mbps        330.0
# late_payments_last_6m      5.0
# promo_active               NaN
# discount_pct              35.0
# churn                      1.0

# %%
df['senior_citizen'].value_counts()
# Out:
# senior_citizen
# 0    5061
# 1     939
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            6000 non-null   str
#  1   gender                 6000 non-null   str
#  2   senior_citizen         6000 non-null   int64
#  3   partner                6000 non-null   str
#  4   dependents             6000 non-null   str
#  5   tenure_months          6000 non-null   int64
#  6   phone_service          6000 non-null   str
#  7   multiple_lines         6000 non-null   str
#  8   internet_service       6000 non-null   str
#  9   online_security        6000 non-null   str
#  10  online_backup          6000 non-null   str
#  11  device_protection      6000 non-null   str
#  12  tech_support           6000 non-null   str
#  13  streaming_tv           6000 non-null   str
#  14  streaming_movies       6000 non-null   str
#  15  contract               6000 non-null   str
#  16  paperless_billing      6000 non-null   str
#  17  payment_method         6000 non-null   str
#  18  monthly_charges        6000 non-null   float64
#  19  total_charges          5926 non-null   float64
#  20  complaints_last_3m     6000 non-null   int64
#  21  outages_last_3m        6000 non-null   int64
#  22  avg_download_mbps      5954 non-null   float64
#  23  late_payments_last_6m  6000 non-null   int64
#  24  promo_active           6000 non-null   str
#  25  discount_pct           6000 non-null   float64
#  26  churn                  6000 non-null   int64
# dtypes: float64(4), int64(6), str(17)
# memory usage: 1.2 MB

# %%
df["churn"].value_counts()
# Out:
# churn
# 0    5157
# 1     843
# Name: count, dtype: int64

# %%
df["churn"].value_counts(normalize=True)
# Out:
# churn
# 0    0.8595
# 1    0.1405
# Name: proportion, dtype: float64

# %%
df["churn"].value_counts(normalize=True) * 100
# Out:
# churn
# 0    85.95
# 1    14.05
# Name: proportion, dtype: float64

# %%
pd.crosstab(df["contract"], df["churn"], normalize="index")
# Out:
# churn                  0         1
# contract
# Month-to-month  0.804264  0.195736
# One year        0.927720  0.072280
# Two year        0.933646  0.066354

# %%
# taxa média de churn por tempo de contrato
churn_by_contract = (
    df.groupby("contract")["churn"].mean()
    .sort_values(ascending=False)
)

# plot (Gráfico)
plt.figure(figsize=(7,5))
churn_by_contract.plot(kind="bar", color="black")

plt.title("Taxa de Churn por Tipo de Contrato")
plt.ylabel("Taxa de Churn")
plt.xlabel("Tipo de Contrato")
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()
